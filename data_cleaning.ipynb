# %%
import pandas as pd

# %%
df = pd.read_csv('/content/trip_data/combined_file.csv')
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1         1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2         1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3         1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4         1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# 5         1  2019-08-01 00:47:20   2019-08-01 01:21:45              1.0
# 6         1  2019-08-01 00:19:46   2019-08-01 00:20:06              1.0
# 7         2  2019-08-01 00:22:12   2019-08-01 00:22:38              1.0
# 8         2  2019-08-01 00:34:36   2019-08-01 00:35:16              1.0
# 9         1  2019-08-01 00:16:25   2019-08-01 00:48:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N         145.0         145.0
# ...

# %%
df['airport_fee'].unique()
# Out:
# array([nan])

# %%
df = df.drop('airport_fee', axis=1)

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1               1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2               1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3               1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4               1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# ...           ...                  ...                   ...              ...
# 2846182         2  2019-02-02 14:31:09   2019-02-02 14:38:35              1.0
# 2846183         2  2019-02-02 14:44:14   2019-02-02 15:23:22              1.0
# 2846184         2  2019-02-02 14:17:25   2019-02-02 14:40:06              1.0
# 2846185         2  2019-02-02 14:48:28   2019-02-02 14:53:04              1.0
# 2846186         2             2019-02-                   NaN              NaN
#
# ...

# %%
df['store_and_fwd_flag'].unique()
# Out:
# array(['N', 'Y', nan], dtype=object)

# %%
print(len(df))
print(len(df.columns))
# Out:
# 2846187
# 18

# %%
num_duplicates = df.duplicated().sum()
print(num_duplicates)
# Out:
# 44

# %%
df.drop_duplicates(keep=False, inplace=True)

# %%
print(len(df))
print(len(df.columns))
# Out:
# 2846142
# 18

# %%
df.drop_duplicates(keep=False, inplace=True)

# %%
print(len(df))
print(len(df.columns))
# Out:
# 2846142
# 18

# %%
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1         1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2         1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3         1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4         1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# 5         1  2019-08-01 00:47:20   2019-08-01 01:21:45              1.0
# 6         1  2019-08-01 00:19:46   2019-08-01 00:20:06              1.0
# 7         2  2019-08-01 00:22:12   2019-08-01 00:22:38              1.0
# 8         2  2019-08-01 00:34:36   2019-08-01 00:35:16              1.0
# 9         1  2019-08-01 00:16:25   2019-08-01 00:48:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N         145.0         145.0
# ...

# %%
print(df.dtypes)
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID             float64
# DOLocationID             float64
# payment_type             float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         2
# passenger_count               2
# trip_distance                 3
# RatecodeID                    3
# store_and_fwd_flag            5
# PULocationID                  6
# DOLocationID                  7
# payment_type                  7
# fare_amount                   7
# extra                         8
# mta_tax                       8
# tip_amount                    8
# tolls_amount                  9
# improvement_surcharge        10
# total_amount                 10
# congestion_surcharge     433294
# dtype: int64

# %%
print(len(df))
print(len(df.columns))
# Out:
# 2846142
# 18

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1               1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2               1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3               1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4               1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# ...           ...                  ...                   ...              ...
# 2846182         2  2019-02-02 14:31:09   2019-02-02 14:38:35              1.0
# 2846183         2  2019-02-02 14:44:14   2019-02-02 15:23:22              1.0
# 2846184         2  2019-02-02 14:17:25   2019-02-02 14:40:06              1.0
# 2846185         2  2019-02-02 14:48:28   2019-02-02 14:53:04              1.0
# 2846186         2             2019-02-                   NaN              NaN
#
# ...

# %%
df.dropna(inplace=True)

# %%
print(len(df))
print(len(df.columns))
# Out:
# 2412848
# 18

# %%
# Convert time columns to datetime objects if they aren't already
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# Calculate trip duration in seconds
df['trip_duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds()

# %%
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1         1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2         1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3         1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4         1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# 5         1  2019-08-01 00:47:20   2019-08-01 01:21:45              1.0
# 6         1  2019-08-01 00:19:46   2019-08-01 00:20:06              1.0
# 7         2  2019-08-01 00:22:12   2019-08-01 00:22:38              1.0
# 8         2  2019-08-01 00:34:36   2019-08-01 00:35:16              1.0
# 9         1  2019-08-01 00:16:25   2019-08-01 00:48:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N         145.0         145.0
# ...

# %%
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1         1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2         1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3         1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4         1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# 5         1  2019-08-01 00:47:20   2019-08-01 01:21:45              1.0
# 6         1  2019-08-01 00:19:46   2019-08-01 00:20:06              1.0
# 7         2  2019-08-01 00:22:12   2019-08-01 00:22:38              1.0
# 8         2  2019-08-01 00:34:36   2019-08-01 00:35:16              1.0
# 9         1  2019-08-01 00:16:25   2019-08-01 00:48:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N         145.0         145.0
# ...

# %%
# Calculate average speed in distance unit per hour (assuming 'trip_distance' is in miles)
df['average_speed'] = df['trip_distance'] / (df['trip_duration'] / 3600)

# %%
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1         1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2         1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3         1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4         1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# 5         1  2019-08-01 00:47:20   2019-08-01 01:21:45              1.0
# 6         1  2019-08-01 00:19:46   2019-08-01 00:20:06              1.0
# 7         2  2019-08-01 00:22:12   2019-08-01 00:22:38              1.0
# 8         2  2019-08-01 00:34:36   2019-08-01 00:35:16              1.0
# 9         1  2019-08-01 00:16:25   2019-08-01 00:48:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N         145.0         145.0
# ...

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'trip_duration',
#        'average_speed'],
#       dtype='object')

# %%
# Convert pickup_datetime to datetime objects if it isn't already
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# Filter data for the year 2019
df = df[df['tpep_pickup_datetime'].dt.year == 2019]

print(len(df))
# Out:
# 2412832

# %%
# Convert pickup_datetime to datetime objects if it isn't already
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# Extract the date from pickup_datetime
df['pickup_date'] = df['tpep_pickup_datetime'].dt.date

# Group by pickup date and calculate total trips and average fare
daily_summary = df.groupby('pickup_date').agg(
    total_trips=('tpep_pickup_datetime', 'count'),
    average_fare=('fare_amount', 'mean')
)

print(daily_summary)
# Out:
# <ipython-input-90-e3b8caccaaa0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
# <ipython-input-90-e3b8caccaaa0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_date'] = df['tpep_pickup_datetime'].dt.date
#              total_trips  average_fare
# pickup_date
# 2019-01-01             1      6.500000
# 2019-01-28             3      0.010000
# 2019-01-30             1      0.000000
# ...

# %%
# Convert pickup_datetime to datetime objects if it isn't already
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# Filter data for the year 2019
df = df[df['tpep_pickup_datetime'].dt.year == 2019]

print(df)
print(len(df))
# Out:
# <ipython-input-91-037889ed30ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1               1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2               1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3               1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4               1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# ...           ...                  ...                   ...              ...
# ...

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1               1  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2               1  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3               1  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4               1  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
# ...           ...                  ...                   ...              ...
# 2846181         2  2019-02-02 14:14:33   2019-02-02 14:28:04              1.0
# 2846182         2  2019-02-02 14:31:09   2019-02-02 14:38:35              1.0
# 2846183         2  2019-02-02 14:44:14   2019-02-02 15:23:22              1.0
# 2846184         2  2019-02-02 14:17:25   2019-02-02 14:40:06              1.0
# 2846185         2  2019-02-02 14:48:28   2019-02-02 14:53:04              1.0
#
# ...

# %%
# Convert pickup_datetime to datetime objects if it isn't already
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# Extract the date from pickup_datetime
df['pickup_date'] = df['tpep_pickup_datetime'].dt.date

# Group by pickup date and calculate total trips and average fare
daily_summary = df.groupby('pickup_date').agg(
    total_trips=('tpep_pickup_datetime', 'count'),
    average_fare=('fare_amount', 'mean')
)
print(daily_summary)
# Out:
#              total_trips  average_fare
# pickup_date
# 2019-01-01             1      6.500000
# 2019-01-28             3      0.010000
# 2019-01-30             1      0.000000
# 2019-01-31           305     13.577049
# 2019-02-01        298025     12.242328
# 2019-02-02        121753     11.262690
# 2019-02-03             1     34.500000
# 2019-02-19             6     94.085000
# 2019-02-28           312     15.277244
# 2019-03-01        281140     12.889654
# 2019-03-02        137736     11.855690
# 2019-03-03            18     10.777778
# 2019-03-05             1     10.000000
# 2019-03-21             3     10.666667
# 2019-03-22             1      8.500000
# 2019-03-31           154     17.353896
# 2019-04-01        232855     13.251790
# 2019-04-02        185654     13.120460
# 2019-04-03             4     14.500000
# 2019-04-11             3      6.333333
# 2019-04-12             2     28.250000
# 2019-04-29             3     13.500000
# 2019-04-30           206     14.412621
# ...

# %%
df.to_csv('/content/trip_data/processed_data.csv', index=False)
